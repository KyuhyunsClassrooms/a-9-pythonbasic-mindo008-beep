# %% [markdown]
# # 1차시. notebook 사용법과 변수 읽기
#
# ## 오늘의 목표
# - Jupyter notebook에서 셀을 실행할 수 있다.
# - `print()`, 문자열, 숫자, 변수의 역할을 말할 수 있다.
# - 코드를 실행하기 전에 출력 결과를 먼저 예측할 수 있다.
#
# ## 오늘의 약속
# 1. 셀은 **위에서 아래로** 실행한다.
# 2. 실행 전에 **결과를 먼저 예측**한다.
# 3. 모르면 바로 정답을 찾기보다 **어느 줄이 이해되지 않는지** 적는다.

# %% [markdown]
# ## notebook에서 꼭 알아둘 것
#
# - **코드 셀**: 파이썬 코드를 실행하는 칸
# - **마크다운 셀**: 설명이나 생각을 적는 칸
# - 셀을 실행할 때는 보통 **Shift + Enter**를 사용한다.
# - 변수를 쓰는 셀보다 먼저 실행하지 않으면 오류가 날 수 있다.

# %%
print("환경 확인 완료! 이 문장이 보이면 notebook 실행이 잘 된 것입니다.")
# Out:
# 환경 확인 완료! 이 문장이 보이면 notebook 실행이 잘 된 것입니다.

# %% [markdown]
# ## 1. `print()` 는 화면에 보여 주는 명령
#
# 아래 코드는 어떤 결과가 나올지 먼저 예측해 보세요.
# 예측한 뒤에 셀을 실행하세요.

# %%
print("파이썬 수업 시작!")
print(2026)
print("2026")
# Out:
# 파이썬 수업 시작!
# 2026
# 2026

# %% [markdown]
# ### 기록하기
# - 첫 번째 줄은 무엇을 출력했나요?
# - 두 번째 줄은 무엇을 출력했나요?
# - 문자열과 숫자는 어떻게 달라 보였나요?

# %% [markdown]
# 여기에 적으세요.
#
# - 첫 번째 줄:
# - 두 번째 줄:
# - 문자열과 숫자의 차이:

# %% [markdown]
# ## 2. 변수는 값을 이름표와 함께 저장한다
#
# `=` 는 **같다**라기보다,
# 오른쪽 값을 왼쪽 이름에 **저장한다**고 읽으면 편합니다.

# %%
name = "지민"
school_level = "고등학생"

print(name)
print(school_level)
# Out:
# 지민
# 고등학생

# %% [markdown]
# ### 읽어 보기
# - `name`에는 무엇이 저장되었나요?
# - `school_level`에는 무엇이 저장되었나요?
# - 따옴표가 있는 값은 보통 무엇인가요?

# %% [markdown]
# 여기에 적으세요.
#
# - `name`:
# - `school_level`:
# - 따옴표가 있는 값:

# %% [markdown]
# ## 3. 숫자 변수는 계산에 사용할 수 있다

# %%
age = 17
next_age = age + 1

print(age)
print(next_age)
# Out:
# 17
# 18

# %% [markdown]
# ### 생각하기
# - `next_age`는 왜 18이 되었나요?
# - `age + 1` 에서 `age`는 숫자로 읽히나요, 글자로 읽히나요?

# %% [markdown]
# 여기에 적으세요.
#
# - `next_age`가 18이 된 이유:
# - `age`는 숫자인가, 글자인가:

# %% [markdown]
# ## 4. `len()` 과 `type()` 으로 값의 길이와 종류를 볼 수 있다

# %%
message = "인공지능 수업"
age = 17

print(len(message))
print(type(message))
print(type(age))
# Out:
# 7
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### 읽어 보기
# - `len(message)` 는 무엇을 세나요?
# - `type(message)` 와 `type(age)` 결과는 어떻게 달랐나요?

# %% [markdown]
# 여기에 적으세요.
#
# - `len(message)`:
# - `type(message)`:
# - `type(age)`:

# %% [markdown]
# ## 5. 주석은 사람을 위한 설명문이다
#
# `#` 뒤의 내용은 컴퓨터가 실행하지 않습니다.

# %%
# 주석은 컴퓨터가 실행하지 않는 설명문입니다.
favorite_ai = "생성형 AI"
print(favorite_ai)
# Out:
# 생성형 AI

# %% [markdown]
# ## 6. 한 줄만 바꿔 보기
#
# 아래 코드에서 `"OOO"` 부분을 자신의 이름이나 별명으로 바꿔 보세요.
# 실행 전에 어떤 문장이 나올지 먼저 예측하세요.

# %%
student_name = "OOO"
favorite_subject = "인공지능"

print(student_name + " 학생은 " + favorite_subject + "를 공부합니다.")

# %% [markdown]
# ## 7. 미니 읽기 연습
#
# 아래 코드를 보고 출력 결과를 먼저 적은 뒤 실행하세요.

# %%
title = "AI"
count = 3

print(title)
print(count * 2)
print(len(title))
# Out:
# AI
# 6
# 2

# %% [markdown]
# 여기에 적으세요.
#
# - 첫 번째 출력:AI
# - 두 번째 출력:6
# - 세 번째 출력:2
# - 각 줄의 의미:

# %% [markdown]
# ## 오늘의 정리
#
# 오늘 꼭 기억할 것
#
# - `print()` : 화면에 보여 주기
# - `=` : 값을 저장하기
# - 문자열은 보통 따옴표로 감싼다
# - 셀 실행 순서가 매우 중요하다

# %% [markdown]
# ## 종료 티켓
#
# 아래 문장을 완성해 보세요.
#
# 1. `=` 는 값을 ____________________.
# 2. `print()` 는 ____________________.
# 3. 오늘 가장 헷갈렸던 기호나 문법은 ____________________.

# %% [markdown]
# ## 제출 전 확인
#
# - notebook을 위에서 아래로 끝까지 실행했나요?
# - 마크다운 셀에 자신의 설명을 적었나요?
# - 저장한 뒤 commit / sync 했나요?
